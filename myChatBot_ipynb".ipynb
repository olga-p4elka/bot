# %%
# !pip install python-telegram-bot --upgrade

# %%
import random
import nltk

# %%
BOT_CONFIG = {
    'intents': {
        'hello': {
            'examples': ['привет!',
                         'хай!!!',
                         'прив',
                         'здравствуйте',
                         'салют'],
            'responses': ['Здравствуйте ( ◡‿◡ )',
                          'Hi!', 'Hello :-)',
                          'Привет (｡◕‿◕｡)', 'Приветствую ๏̮͡๏',
                          'здравия желаю (✯◡✯)', 'ассаламу алейкум ٩(͡๏̯͡๏)۶',
                          'сколько лет, сколько зим (⊙_⊙)',
                          'доброго времени суток ≧(◕ ‿‿ ◕)≦']
        },
        'bye': {
            'examples': ['пока!',
                         'покеда!!!',
                         'до свиданья',
                         'спасибо',
                         'бай'],
            'responses': ['увидимся))♡',
                          'до связи (´｡• ᵕ •｡) ♡',
                          'пока-пока♡( ◡‿◡ )',
                          'всего хорошего(づ ◕‿◕ )づ',
                          'до свиданья(▽◕ ᴥ ◕▽)', 'до новых встречV●ᴥ●V',
                          'звони-пиши!',
                          'счастливоʕ •̀ o •́ ʔ',
                          'честь имею!']
        },
        'how': {
            'examples': ['как дела?',
                         'как оно?',
                         'как жизнь?',
                         'как настроение?',
                         'как ты?',
                         'как поживаешь?'],
            'responses': ['все хорошо, надеюсь как и у тебя))♡',
                          'Эх, какие у нас дела? У нас с тобой делишки, а ДЕЛА у прокурора  (´｡• ᵕ •｡) ♡',
                          'Отлично! Чего и вам желаю ♡( ◡‿◡ )', 'я ловлю твои эмоции(づ ◕‿◕ )づ',
                          'как и у тебя, все под контролем(▽◕ ᴥ ◕▽)',
                          'Ах я бедный-несчастный, так устал, мне каждый день приходится придумывать ответ на вопрос «Как дела?»V●ᴥ●V',
                          'Вы несравненно оригинальны в своих вопросах!', '«Хреношо» (где тут ошибка, знаешь только ты)ʕ •̀ o •́ ʔ',
                          'В душе осталась горстка пепла и плоть изношена дотла. Но обстоят великолепно мои душевные дела! Надеюсь, ты тоже держишься♡']
        },
        'who': {
            'examples': ['кто ты?',
                         'ты кто?',
                         'кто вы?',
                         'что ты делаешь?',
                         'чем ты занимаешься?'],
            'responses': ['Я простой и точный магический бот с несколькими вариантами ответов: "да", "нет", "скоро" и "почти" ( ◡‿◡ )\nМеня можно использовать в любых случаях, когда не требуется больших философских отступлений, а нужно просто узнать ответ на вопрос (｡◕‿◕｡)\nПонятно, что ко мне большинство будет относиться как к развлечению ๏̮͡๏\nНо всё же старайся использовать меня только тогда, когда тебе действительно нужен ответ на важный вопрос ٩(͡๏̯͡๏)۶\nПоменьше сомнений и в твоей жизни будет намного больше чудес и волшебства... (✯◡✯)\nДля получения ответа нужно сосредоточится на вопросе и задать его (⊙_⊙)\nПосле получения ответа от оракула можно будет снова задать вопрос ≧(◕ ‿‿ ◕)≦']
        },
    },
     'answer': {
            'example': ['?'],
            'response': [ 'Бесспорно',
                         'Предрешено',
                         'Никаких сомнений',
                         'Определённо да',
                         'Можешь быть уверен в этом',
                         'Мне кажется — «да»',
                         'Вероятнее всего',
                         'Хорошие перспективы',
                         'Знаки говорят — «да»',
                         'Да',
                         'Пока не ясно, попробуй снова',
                         'Спроси позже',
                         'Лучше не рассказывать',
                         'Сейчас нельзя предсказать',
                         'Сконцентрируйся и спроси опять',
                         'Даже не думай',
                         'Мой ответ — «нет»',
                         'По моим данным — «нет»',
                         'Перспективы не очень хорошие',
                         'Весьма сомнительно']
        }
}

# %%
def clean(text):
  clean_text = ''
  for ch in text.lower():
    if ch in 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя':
      clean_text = clean_text + ch
  return clean_text

def clean2(text):
  clean_text = ''
  for ch in text.lower():
    if ch in '?':
      clean_text = '?'
  return clean_text

def get_intent(text):
  for intent in BOT_CONFIG['intents'].keys():
    for example in BOT_CONFIG['intents'][intent]['examples']:
      s1 = clean(text)
      s2 = clean(example)
      if nltk.edit_distance(s1, s2) / max(len(s1), len(s2)) < 0.4:
        return intent
  return 'интент не найден'

def bot(input_text):
  intent = get_intent(input_text)
  if intent != 'интент не найден':
    return random.choice(BOT_CONFIG['intents'][intent]['responses'])
  else:
    return 'интент-вопрос'

def get_answer(input_text):
  out = 'интент не найден'
  s1 = clean2(input_text)
  s2 = BOT_CONFIG['answer']['example'][0]
  if s1 == s2:
    out = random.choice(BOT_CONFIG['answer']['response'])
  return out

def out_text(text):
  input_text = text
  response = bot(input_text)
  if response == 'интент-вопрос':
      answer = get_answer(input_text)
      if answer == 'интент не найден':
        return 'Воспользуйся командой /help ♡( ◡‿◡ )'
      else:
        return answer
  else:
    return response

# %%
import logging

from telegram import Update, ForceReply
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters, CallbackContext

# Enable logging
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level=logging.INFO
)

logger = logging.getLogger(__name__)


# Define a few command handlers. These usually take the two arguments update and
# context.
def start(update: Update, context: CallbackContext) -> None:
    """Send a message when the command /start is issued."""
    user = update.effective_user
    update.message.reply_markdown_v2(
        fr'{user.mention_markdown_v2()}\, тебя приветствует магический бот ◕‿◕',
        reply_markup=ForceReply(selective=True),
    )


def help_command(update: Update, context: CallbackContext) -> None:
    """Send a message when the command /help is issued."""
    update.message.reply_text('Задай мне интересующий тебя вопрос... в закрытой форме... и я помогу тебе с ответом... ʕ ᵔᴥᵔ ʔ')

def echo(update: Update, context: CallbackContext) -> None:
    """Echo the user message."""
    input_text = update.message.text
    output_text = out_text(input_text)
    update.message.reply_text(output_text)


def main() -> None:
    """Start the bot."""
    # Create the Updater and pass it your bot's token.
    updater = Updater("5073013457:AAFF8c45YrbAmj8KNxauNzzphDFtwFvZj8g")

    # Get the dispatcher to register handlers
    dispatcher = updater.dispatcher

    # on different commands - answer in Telegram
    dispatcher.add_handler(CommandHandler("start", start))
    dispatcher.add_handler(CommandHandler("help", help_command))

    # on non command i.e message - echo the message on Telegram
    dispatcher.add_handler(MessageHandler(Filters.text & ~Filters.command, echo))

    # Start the Bot
    updater.start_polling()

    # Run the bot until you press Ctrl-C or the process receives SIGINT,
    # SIGTERM or SIGABRT. This should be used most of the time, since
    # start_polling() is non-blocking and will stop the bot gracefully.
    updater.idle()


if __name__ == '__main__':
  main()
